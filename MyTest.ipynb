# %% [markdown]
# <a href="https://colab.research.google.com/github/ravichas/bifx-546/blob/main/MyTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is a test

# %%
import numpy as np

# %%
x = 1.0
y = 2.00
x + y
# Out:
# 3.0
