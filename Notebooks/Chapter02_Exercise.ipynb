# %% [markdown]
# <a href="https://colab.research.google.com/github/ravichas/bifx-546/blob/main/Notebooks/Chapter02_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Chapter 2: Python 101

# %% [markdown]
# 🎓 Course Context
#
# Prepared for BIFX-546 – Machine Learning for Bioinformatics
#
# Instructor: Sarangan Ravichandran, PhD., PMP

# %% [markdown]
# # 📘 Attribution & Reading Reference
#
# This notebook is based on concepts, structure and examples from,
#
# Data Science from Scratch, 2nd Edition by Joel Grus,published by O'Reilly Media,Inc.
#
# # Relevant Reading:
#
# Data Science from Scratch, 2nd Edition — Chapter 2: [A Crash Course in Python]

# %%
# =========================
# Exercise: Patient Metadata (Pure Python)
# =========================

patients = [
    {"id": "P001", "age": 45, "sex": "F", "diagnosis": "diabetes", "bmi": 31.2},
    {"id": "P002", "age": 60, "sex": "M", "diagnosis": "hypertension", "bmi": 27.8},
    {"id": "P003", "age": 38, "sex": "F", "diagnosis": "diabetes", "bmi": 29.4},
    {"id": "P004", "age": 50, "sex": "M", "diagnosis": "none", "bmi": 24.1},
    {"id": "P005", "age": 72, "sex": "F", "diagnosis": "hypertension", "bmi": 26.5},
]

# %%
import pandas as pd
pd.DataFrame(patients)
# Out:
#      id  age sex     diagnosis   bmi
# 0  P001   45   F      diabetes  31.2
# 1  P002   60   M  hypertension  27.8
# 2  P003   38   F      diabetes  29.4
# 3  P004   50   M          none  24.1
# 4  P005   72   F  hypertension  26.5

# %% [markdown]
# # ---- Student TODOs ----

# %%
def count_by_diagnosis(patients):
    """
    Return a dictionary mapping diagnosis -> count

    Expected output:
    {'diabetes': 2, 'hypertension': 2, 'none': 1}
    """
    pass

# %%
def average_bmi(patients):
    """
    Return the average BMI across all patients

    Expected output:
    27.8  (approximately)
    """
    pass

# %%
def high_risk_patients(patients, age_threshold=60, bmi_threshold=30):
    """
    Return a list of patient IDs where:
    age >= age_threshold OR bmi >= bmi_threshold

    Expected output:
    ['P001', 'P002', 'P005']
    """
    pass

# %%
# ---- Simple checks (instructor-provided) ----

assert count_by_diagnosis(patients) == {"diabetes": 2, "hypertension": 2, "none": 1}
assert round(average_bmi(patients), 2) == round((31.2 + 27.8 + 29.4 + 24.1 + 26.5) / 5, 2)
assert high_risk_patients(patients) == ["P001", "P002", "P005"]  # bmi>=30 OR age>=60

print("All checks passed!")
print("Counts:", count_by_diagnosis(patients))
print("Avg BMI:", average_bmi(patients))
print("High-risk IDs:", high_risk_patients(patients))
